# %%
import pandas as pd

# %%
info_mp_candidate = pd.read_json('../data/info_mp_candidate.json')
info_party_overview = pd.read_json('../data/info_party_overview.json')
stats_party = pd.read_json('../data/stats_party.json')

# %%
info_mp_candidate.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3491 entries, 0 to 3490
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   mp_app_id        3491 non-null   str
#  1   mp_app_no        3491 non-null   int64
#  2   mp_app_party_id  3488 non-null   float64
#  3   mp_app_name      3491 non-null   str
#  4   image_url        3491 non-null   str
# dtypes: float64(1), int64(1), str(3)
# memory usage: 136.5 KB

# %%
info_party_overview.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 57 entries, 0 to 56
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        57 non-null     int64
#  1   party_no  57 non-null     int64
#  2   name      57 non-null     str
#  3   abbr      56 non-null     str
#  4   color     57 non-null     str
#  5   logo_url  57 non-null     str
# dtypes: int64(2), str(4)
# memory usage: 2.8 KB

# %%
stats_party.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 57 entries, 0 to 56
# Data columns (total 4 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   counted_vote_stations  57 non-null     int64
#  1   percent_count          57 non-null     float64
#  2   result_party           57 non-null     object
#  3   last_update            57 non-null     str
# dtypes: float64(1), int64(1), object(1), str(1)
# memory usage: 1.9+ KB

# %%
stats_party['result_party']
# Out:
# 0     {'party_id': 254, 'party_vote': 284761, 'party...
# 1     {'party_id': 185, 'party_vote': 628493, 'party...
# 2     {'party_id': 244, 'party_vote': 294239, 'party...
# 3     {'party_id': 228, 'party_vote': 230170, 'party...
# 4     {'party_id': 250, 'party_vote': 403671, 'party...
# 5     {'party_id': 229, 'party_vote': 705035, 'party...
# 6     {'party_id': 217, 'party_vote': 108235, 'party...
# 7     {'party_id': 109, 'party_vote': 237672, 'party...
# 8     {'party_id': 34, 'party_vote': 5147600, 'party...
# 9     {'party_id': 170, 'party_vote': 156704, 'party...
# 10    {'party_id': 173, 'party_vote': 1045452, 'part...
# 11    {'party_id': 145, 'party_vote': 170156, 'party...
# 12    {'party_id': 255, 'party_vote': 182255, 'party...
# 13    {'party_id': 242, 'party_vote': 44567, 'party_...
# 14    {'party_id': 56, 'party_vote': 27660, 'party_v...
# 15    {'party_id': 204, 'party_vote': 66966, 'party_...
# 16    {'party_id': 237, 'party_vote': 48695, 'party_...
# ...
